# %%
import torch

path = './checkpoint/resnet18_places365.pth.tar'
try:
    checkpoint = torch.load(path, map_location='cpu')
    print("✅ 文件完整，包含键：", checkpoint.keys())
except Exception as e:
    print("❌ 文件损坏：", e)
# Out:
# ❌ 文件损坏： unexpected EOF, expected 2106164 more bytes. The file might be corrupted.
